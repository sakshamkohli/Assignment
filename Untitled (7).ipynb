# %% [raw]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [raw]
# Flask is a framework used to develop[ web application and to establish a link between the server and the website. The advantages of flask are as follows:
# highly scalable
# establishes a connection between frontend and backend irrespective of them being i. different languages
# relaible

# %% [raw]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %% [markdown]
# ![Screenshot 2023-06-27 at 9.14.09 PM.png](attachment:623772c9-6cd9-4c95-870a-714980bec392.png)

# %% [raw]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [raw]
# App routing is a process in flask which allows the request recieved from the frontend to go to the intended function only. We need this to ensure that the requests to the backend are fulfilled and do not go to the wrong function leading to unfulfilled request

# %% [raw]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %% [markdown]
# ![Screenshot 2023-06-27 at 9.32.50 PM.png](attachment:724d222b-59f4-4539-b7d8-bbf93c95a47e.png)

# %% [markdown]
# ![Screenshot 2023-06-27 at 9.33.02 PM.png](attachment:5c762f20-8f47-4869-92a6-537e0a530edd.png)
